# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\Machine Learning\pandas\laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head()  # shows the first 5 rows of data
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.head(10)  # showing the first 10 rows of data
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail()  # showing the last 5
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.tail(10) # showing the last 10 rows data
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 813    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 814    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 815    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 816    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
df.info() # provide the whole information about it
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.dtypes  # define the types of data in data set
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.describe()  #describe the all values of total
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.columns  # define the name of all column
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
num_columns=df.select_dtypes(exclude='O')  # gives the data type to print the numericalndata

# %%
num_columns
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
cat_column=df.select_dtypes(include='O')  # gives the data set includes the object or categorical data

# %%
cat_column
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
num_columns.head() #gives the five term values
# Out:
#    Price  Number of Ratings  Number of Reviews
# 0  34649                  3                  0
# 1  38999                 65                  5
# 2  39999                  8                  1
# 3  69990                  0                  0
# 4  26990                  0                  0

# %%
cat_column['brand'].unique() # provide the unique value of brand
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
cat_column['brand'].nunique() #provide the number of unique value
# Out:
# 8

# %%
cat_column['processor_brand'].unique()  # define the unique processor brand
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
cat_column['processor_brand'].nunique()  # define the number of unique processor brand
# Out:
# 3

# %%
cat_column['processor_name'].unique()  # define the
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
cat_column['processor_name'].nunique()  # define the processor name value
# Out:
# 11

# %%
cat_column['processor_gnrtn'].unique()  # define the  unique processor generation
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
cat_column['processor_gnrtn'].nunique()  # define the number of unique processor gneration
# Out:
# 8

# %%
cat_column['ram_gb'].unique()  # deine the unique ram gb
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
cat_column['ram_gb'].nunique() # define the number of unique ram gb
# Out:
# 4

# %%
cat_column['ram_type'].unique() # define the unique ram type
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
cat_column['ram_type'].nunique()  # define the  number of unique ram type
# Out:
# 6

# %%
cat_column['ssd'].unique() # define the unique ssd
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
cat_column['ssd'].nunique()  # define the number of unique ssd
# Out:
# 7

# %%
cat_column['hdd'].unique()   # define the unique hdd
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
cat_column['hdd'].nunique()  # define the number of unique hdd
# Out:
# 4

# %%
cat_column['os'].unique()  # define the unique os
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
cat_column['os'].nunique()  # define the number of unique os
# Out:
# 3

# %%
cat_column['os_bit'].unique()  # define the unique os bit
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
cat_column['os_bit'].nunique()  # define the number of unique os bit
# Out:
# 2

# %%
cat_column['graphic_card_gb'].unique()  #
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
cat_column['graphic_card_gb'].nunique()
# Out:
# 5

# %%
cat_column['weight'].unique()
# Out:
# array(['Casual', 'ThinNlight', 'Gaming'], dtype=object)

# %%
cat_column['weight'].nunique()
# Out:
# 3

# %%
cat_column['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
cat_column['warranty'].nunique()
# Out:
# 4

# %%
cat_column['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
cat_column['Touchscreen'].nunique()
# Out:
# 2

# %%
cat_column['msoffice'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
cat_column['msoffice'].nunique()
# Out:
# 2

# %%
cat_column['rating'].unique()
# Out:
# array(['2 stars', '3 stars', '4 stars', '5 stars', '1 star'], dtype=object)

# %%
cat_column['rating'].nunique()
# Out:
# 5

# %%
df['brand'].value_counts() # use to count the values of particular company
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
apple=df[df['brand']=="APPLE"]  # to get the data set of only APPLE brand

# %%
apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
apple['processor_brand'].unique()  #define the brand of apple
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
apple_m1_chip=apple[apple['processor_brand']=='m1']  #

# %%
apple_m1_chip
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
apple_m1_touchscreen=apple[apple['Touchscreen']=='m1']

# %%
apple_m1_touchscreen
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
apple.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count      28.000000          28.000000          28.000000
# mean   151707.857143        1207.535714         117.535714
# std     54907.255498        2310.990913         214.853866
# min     85990.000000           3.000000           1.000000
# 25%    104990.000000          42.000000           5.000000
# 50%    132490.000000         253.500000          29.000000
# 75%    179990.000000         640.000000          70.000000
# max    309990.000000        6725.000000         629.000000

# %%
# apple
# processor_brand = intel
# ram = 8gb
# 100000 ke kam vale laptop

# %%
asus=df[df['brand']=="ASUS"]  # to get the data set of only ASUS brand

# %%
asus
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
asus_processor_name=asus[asus['processor_gnrtn']=='10th']
asus_processor_name
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 27   ASUS           Intel        Core i3            10th   8 GB     DDR4
# 60   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 70   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 86   ASUS           Intel        Core i3            10th   8 GB     DDR4
# 89   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 98   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 119  ASUS           Intel        Core i3            10th   4 GB     DDR4
# 120  ASUS           Intel        Core i3            10th   4 GB     DDR4
# 122  ASUS           Intel        Core i3            10th   4 GB     DDR4
# ...

# %%
asus_ram=asus_processor_name[asus_processor_name['ram_type']=='LPDDR3']
asus_ram
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 302  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 381  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 382  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 386  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 541  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 565  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 566  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 568  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 576  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
#
#          ssd   hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 302   512 GB  0 GB  Windows  64-bit            0 GB  Casual       1 year
# 381   512 GB  0 GB  Windows  64-bit            2 GB  Casual       1 year
# ...

# %%
acer=df[df['brand']=="acer"]
acer
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10   acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 11   acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 31   acer           Intel        Core i3            11th   8 GB     DDR4
# 64   acer           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 161  acer           Intel        Core i3            11th   4 GB     DDR4
# 176  acer           Intel        Core i3            11th   8 GB     DDR4
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 197  acer           Intel        Core i5   Not Available   8 GB   LPDDR4
# 198  acer           Intel        Core i5            10th   8 GB   LPDDR4
# 207  acer           Intel        Core i5             7th   8 GB     DDR3
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
# ...

# %%
acer_specific=acer[acer["Touchscreen"]=="Yes"]
acer_specific
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
# 365  acer           Intel        Core i5            11th   8 GB     DDR4
#
#         ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 210  256 GB  0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 365  512 GB  0 GB  Windows  64-bit            0 GB  ThinNlight  No warranty
#
#     Touchscreen msoffice   Price   rating  Number of Ratings  \
# 210         Yes      Yes   81998  4 stars                 14
# 365         Yes       No  109999  3 stars                  0
#
#      Number of Reviews
# 210                  3
# 365                  0
